# %% [markdown]
# <a href="https://colab.research.google.com/github/amk735/DS340W-project-flower-image-classification/blob/main/ResNetandTransferLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
#!ls

# %%
#%cd gdrive/MyDrive/DS340

# %%
#! git clone https://github.com/amk735/DS340W-project-flower-image-classification

# %%
#!git clone https://github.com/amk735/DS340W-project-flower-image-classification/tree/main/Few-Shot-Limited-Data-main/MAML/flowerImages
#clone dataset

# %%
import os
import numpy as np

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras import optimizers, callbacks
import tensorflow.keras.backend as K

# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
config = tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
gpus = tf.config.experimental.list_physical_devices('GPU') 
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
image_width = 224
image_height = 224
num_classes = 5
histories = []

# %%
images_dir = "/content/drive/MyDrive/DS340/images/"
train_data_dir = images_dir + "train/" #/content/drive/MyDrive/DS340/images/"#images_dir + "train/"
val_data_dir = images_dir + "val/"
test_data_dir = images_dir + "test/"

# %%
images_dir = "/content/drive/MyDrive/DS340/images/"
flowers_complete = "/content/drive/MyDrive/DS340/flowers/"
train_data_dir = images_dir + "train/" #"/content/drive/MyDrive/DS340/images/"#images_dir + "train/"
val_data_dir = flowers_complete
test_data_dir = flowers_complete #+ "test/"

# %%
checkpoint_dir = "checkpoints/"
checkpoint_name = checkpoint_dir + "flora-transferLearning-{val_loss:.4f}-{val_accuracy:.4f}.hdf5"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# %%
#%matplotlib inline
##import

# %%
def create_callbacks():
    return [
        callbacks.EarlyStopping(monitor="val_accuracy", patience=10, verbose=1),

        callbacks.ModelCheckpoint(checkpoint_name, monitor="val_accuracy", 
                                  verbose=1, save_best_only=True),
    ]

my_callbacks = create_callbacks()

# %%
my_callbacks = create_callbacks()

# %%
# !pip install ResNet34
#import resnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement ResNet34 (from versions: none)
# ERROR: No matching distribution found for ResNet34

# %%
#from tensorflow.keras.applications.vgg19 import VGG19
#from tensorflow.keras.applications.vgg19 import preprocess_input

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

#from tensorflow.keras.applications import ResNet34
#from keras.applications.resnet import resnet
#import resnet34

base_model = ResNet50(input_shape=(image_height, image_width, 3), 
                      include_top=False, weights="imagenet", 
                      pooling=None)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
train_datagen = ImageDataGenerator(
                    rotation_range=40,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    shear_range=0.2,
                    zoom_range=0.2,
                    channel_shift_range=0.2,
                    horizontal_flip=True,
                    fill_mode="nearest",
                    preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
#print(train_data_dir)

# %%
#os.getcwd()

# %%
#os.chdir(/content/drive/MyDrive/Github)

# %%
batch_size = 64

#import os
#print(os.listdir("/content/drive/MyDrive/DS340"))

train_generator = train_datagen.flow_from_directory(
                    train_data_dir + '',
                    target_size=(image_width, image_height),
                    batch_size=batch_size,
                    class_mode="categorical",
                    shuffle=True)

val_generator = val_datagen.flow_from_directory(
                    val_data_dir,
                    target_size=(image_width, image_height),
                    batch_size=batch_size,
                    class_mode="categorical",
                    shuffle=False)

test_generator = test_datagen.flow_from_directory(
                    test_data_dir,
                    target_size=(image_width, image_height),
                    batch_size=batch_size,
                    class_mode="categorical",
                    shuffle=False)
print(train_data_dir)
print(val_data_dir)
print(test_data_dir)
# Out:
# Found 25 images belonging to 5 classes.
# Found 4317 images belonging to 5 classes.
# Found 4317 images belonging to 5 classes.
# /content/drive/MyDrive/DS340/images/train/
# /content/drive/MyDrive/DS340/flowers/
# /content/drive/MyDrive/DS340/flowers/

# %%
#len(val_generator)
val_generator.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
from tensorflow.keras import regularizers

top_model = Sequential()
top_model.add(base_model)
top_model.add(GlobalAveragePooling2D())
top_model.add(Dropout(0.7))
top_model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(0.01)))
top_model.add(Activation("softmax"))

print(top_model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7fc011cca280>

# %%
from tensorflow.keras import regularizers

model = Sequential()
model.add(base_model)
model.add(Conv2D(64, (3, 3), input_shape=(image_height, image_width, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#b
model.add(Conv2D(32, (1, 1)))
model.add(Activation('relu'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation("softmax"))

print(model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7fc0114ecd60>

# %%
for layer in base_model.layers:
    layer.trainable = False

top_model.compile(loss="categorical_crossentropy",
                  optimizer=optimizers.Adam(learning_rate=1e-4), #changed lr to learning_rate
                  metrics=["accuracy"])   

print(top_model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7fc011cca280>

# %%
histories.append(top_model.fit(train_generator, 
                              steps_per_epoch=len(train_generator),
                              epochs=60,
                              callbacks=my_callbacks,
                              validation_data=val_generator,
                              validation_steps=len(val_generator),
                              workers=8))
# Out:
# Epoch 1/60
# 1/1 [==============================] - ETA: 0s - loss: 2.7697 - accuracy: 0.3600
# Epoch 1: val_accuracy improved from -inf to 0.22076, saving model to checkpoints/flora-transferLearning-2.0647-0.2208.hdf5
# 1/1 [==============================] - 121s 121s/step - loss: 2.7697 - accuracy: 0.3600 - val_loss: 2.0647 - val_accuracy: 0.2208
# Epoch 2/60
# 1/1 [==============================] - ETA: 0s - loss: 2.9927 - accuracy: 0.3200
# Epoch 2: val_accuracy improved from 0.22076 to 0.22585, saving model to checkpoints/flora-transferLearning-2.0441-0.2259.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.9927 - accuracy: 0.3200 - val_loss: 2.0441 - val_accuracy: 0.2259
# Epoch 3/60
# 1/1 [==============================] - ETA: 0s - loss: 2.8121 - accuracy: 0.2400
# Epoch 3: val_accuracy improved from 0.22585 to 0.23141, saving model to checkpoints/flora-transferLearning-2.0241-0.2314.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 2.8121 - accuracy: 0.2400 - val_loss: 2.0241 - val_accuracy: 0.2314
# Epoch 4/60
# 1/1 [==============================] - ETA: 0s - loss: 2.9719 - accuracy: 0.3200
# Epoch 4: val_accuracy improved from 0.23141 to 0.23512, saving model to checkpoints/flora-transferLearning-2.0058-0.2351.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 2.9719 - accuracy: 0.3200 - val_loss: 2.0058 - val_accuracy: 0.2351
# Epoch 5/60
# 1/1 [==============================] - ETA: 0s - loss: 2.7699 - accuracy: 0.3600
# Epoch 5: val_accuracy improved from 0.23512 to 0.23697, saving model to checkpoints/flora-transferLearning-1.9889-0.2370.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 2.7699 - accuracy: 0.3600 - val_loss: 1.9889 - val_accuracy: 0.2370
# Epoch 6/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9751 - accuracy: 0.4000
# Epoch 6: val_accuracy improved from 0.23697 to 0.24299, saving model to checkpoints/flora-transferLearning-1.9728-0.2430.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.9751 - accuracy: 0.4000 - val_loss: 1.9728 - val_accuracy: 0.2430
# Epoch 7/60
# 1/1 [==============================] - ETA: 0s - loss: 2.1560 - accuracy: 0.2800
# Epoch 7: val_accuracy improved from 0.24299 to 0.24577, saving model to checkpoints/flora-transferLearning-1.9574-0.2458.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.1560 - accuracy: 0.2800 - val_loss: 1.9574 - val_accuracy: 0.2458
# Epoch 8/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9036 - accuracy: 0.5200
# Epoch 8: val_accuracy improved from 0.24577 to 0.25110, saving model to checkpoints/flora-transferLearning-1.9433-0.2511.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.9036 - accuracy: 0.5200 - val_loss: 1.9433 - val_accuracy: 0.2511
# Epoch 9/60
# 1/1 [==============================] - ETA: 0s - loss: 2.4630 - accuracy: 0.2800
# Epoch 9: val_accuracy improved from 0.25110 to 0.25457, saving model to checkpoints/flora-transferLearning-1.9290-0.2546.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.4630 - accuracy: 0.2800 - val_loss: 1.9290 - val_accuracy: 0.2546
# Epoch 10/60
# 1/1 [==============================] - ETA: 0s - loss: 2.4152 - accuracy: 0.2400
# Epoch 10: val_accuracy improved from 0.25457 to 0.25828, saving model to checkpoints/flora-transferLearning-1.9148-0.2583.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.4152 - accuracy: 0.2400 - val_loss: 1.9148 - val_accuracy: 0.2583
# Epoch 11/60
# 1/1 [==============================] - ETA: 0s - loss: 2.7543 - accuracy: 0.1600
# Epoch 11: val_accuracy improved from 0.25828 to 0.26222, saving model to checkpoints/flora-transferLearning-1.9013-0.2622.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.7543 - accuracy: 0.1600 - val_loss: 1.9013 - val_accuracy: 0.2622
# Epoch 12/60
# 1/1 [==============================] - ETA: 0s - loss: 2.3542 - accuracy: 0.3600
# Epoch 12: val_accuracy improved from 0.26222 to 0.26755, saving model to checkpoints/flora-transferLearning-1.8883-0.2675.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.3542 - accuracy: 0.3600 - val_loss: 1.8883 - val_accuracy: 0.2675
# Epoch 13/60
# 1/1 [==============================] - ETA: 0s - loss: 2.6612 - accuracy: 0.2400
# Epoch 13: val_accuracy improved from 0.26755 to 0.27102, saving model to checkpoints/flora-transferLearning-1.8767-0.2710.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 2.6612 - accuracy: 0.2400 - val_loss: 1.8767 - val_accuracy: 0.2710
# Epoch 14/60
# 1/1 [==============================] - ETA: 0s - loss: 2.5022 - accuracy: 0.3600
# Epoch 14: val_accuracy improved from 0.27102 to 0.27519, saving model to checkpoints/flora-transferLearning-1.8651-0.2752.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.5022 - accuracy: 0.3600 - val_loss: 1.8651 - val_accuracy: 0.2752
# Epoch 15/60
# 1/1 [==============================] - ETA: 0s - loss: 2.0250 - accuracy: 0.4000
# Epoch 15: val_accuracy improved from 0.27519 to 0.27890, saving model to checkpoints/flora-transferLearning-1.8543-0.2789.hdf5
# 1/1 [==============================] - 25s 25s/step - loss: 2.0250 - accuracy: 0.4000 - val_loss: 1.8543 - val_accuracy: 0.2789
# Epoch 16/60
# 1/1 [==============================] - ETA: 0s - loss: 2.3475 - accuracy: 0.3600
# Epoch 16: val_accuracy improved from 0.27890 to 0.28399, saving model to checkpoints/flora-transferLearning-1.8443-0.2840.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.3475 - accuracy: 0.3600 - val_loss: 1.8443 - val_accuracy: 0.2840
# Epoch 17/60
# 1/1 [==============================] - ETA: 0s - loss: 2.2754 - accuracy: 0.3200
# Epoch 17: val_accuracy improved from 0.28399 to 0.28724, saving model to checkpoints/flora-transferLearning-1.8341-0.2872.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.2754 - accuracy: 0.3200 - val_loss: 1.8341 - val_accuracy: 0.2872
# Epoch 18/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9325 - accuracy: 0.3200
# Epoch 18: val_accuracy improved from 0.28724 to 0.29025, saving model to checkpoints/flora-transferLearning-1.8236-0.2902.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.9325 - accuracy: 0.3200 - val_loss: 1.8236 - val_accuracy: 0.2902
# Epoch 19/60
# 1/1 [==============================] - ETA: 0s - loss: 1.7302 - accuracy: 0.4800
# Epoch 19: val_accuracy improved from 0.29025 to 0.29419, saving model to checkpoints/flora-transferLearning-1.8131-0.2942.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.7302 - accuracy: 0.4800 - val_loss: 1.8131 - val_accuracy: 0.2942
# Epoch 20/60
# 1/1 [==============================] - ETA: 0s - loss: 2.3081 - accuracy: 0.3200
# Epoch 20: val_accuracy improved from 0.29419 to 0.29882, saving model to checkpoints/flora-transferLearning-1.8029-0.2988.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.3081 - accuracy: 0.3200 - val_loss: 1.8029 - val_accuracy: 0.2988
# Epoch 21/60
# 1/1 [==============================] - ETA: 0s - loss: 2.3212 - accuracy: 0.3600
# Epoch 21: val_accuracy improved from 0.29882 to 0.30229, saving model to checkpoints/flora-transferLearning-1.7927-0.3023.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.3212 - accuracy: 0.3600 - val_loss: 1.7927 - val_accuracy: 0.3023
# Epoch 22/60
# 1/1 [==============================] - ETA: 0s - loss: 2.0158 - accuracy: 0.4400
# Epoch 22: val_accuracy improved from 0.30229 to 0.30484, saving model to checkpoints/flora-transferLearning-1.7822-0.3048.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.0158 - accuracy: 0.4400 - val_loss: 1.7822 - val_accuracy: 0.3048
# Epoch 23/60
# 1/1 [==============================] - ETA: 0s - loss: 2.2657 - accuracy: 0.3200
# Epoch 23: val_accuracy improved from 0.30484 to 0.30808, saving model to checkpoints/flora-transferLearning-1.7715-0.3081.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.2657 - accuracy: 0.3200 - val_loss: 1.7715 - val_accuracy: 0.3081
# Epoch 24/60
# 1/1 [==============================] - ETA: 0s - loss: 2.2018 - accuracy: 0.2800
# Epoch 24: val_accuracy improved from 0.30808 to 0.31272, saving model to checkpoints/flora-transferLearning-1.7614-0.3127.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 2.2018 - accuracy: 0.2800 - val_loss: 1.7614 - val_accuracy: 0.3127
# Epoch 25/60
# 1/1 [==============================] - ETA: 0s - loss: 2.3581 - accuracy: 0.4000
# Epoch 25: val_accuracy improved from 0.31272 to 0.31550, saving model to checkpoints/flora-transferLearning-1.7519-0.3155.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.3581 - accuracy: 0.4000 - val_loss: 1.7519 - val_accuracy: 0.3155
# Epoch 26/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9323 - accuracy: 0.4400
# Epoch 26: val_accuracy improved from 0.31550 to 0.31851, saving model to checkpoints/flora-transferLearning-1.7429-0.3185.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 1.9323 - accuracy: 0.4400 - val_loss: 1.7429 - val_accuracy: 0.3185
# Epoch 27/60
# 1/1 [==============================] - ETA: 0s - loss: 1.8894 - accuracy: 0.3200
# Epoch 27: val_accuracy improved from 0.31851 to 0.32175, saving model to checkpoints/flora-transferLearning-1.7338-0.3218.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 1.8894 - accuracy: 0.3200 - val_loss: 1.7338 - val_accuracy: 0.3218
# Epoch 28/60
# 1/1 [==============================] - ETA: 0s - loss: 2.6684 - accuracy: 0.3200
# Epoch 28: val_accuracy improved from 0.32175 to 0.32662, saving model to checkpoints/flora-transferLearning-1.7249-0.3266.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.6684 - accuracy: 0.3200 - val_loss: 1.7249 - val_accuracy: 0.3266
# Epoch 29/60
# 1/1 [==============================] - ETA: 0s - loss: 2.3931 - accuracy: 0.2800
# Epoch 29: val_accuracy improved from 0.32662 to 0.33009, saving model to checkpoints/flora-transferLearning-1.7159-0.3301.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.3931 - accuracy: 0.2800 - val_loss: 1.7159 - val_accuracy: 0.3301
# Epoch 30/60
# 1/1 [==============================] - ETA: 0s - loss: 1.8275 - accuracy: 0.3600
# Epoch 30: val_accuracy improved from 0.33009 to 0.33356, saving model to checkpoints/flora-transferLearning-1.7073-0.3336.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 1.8275 - accuracy: 0.3600 - val_loss: 1.7073 - val_accuracy: 0.3336
# Epoch 31/60
# 1/1 [==============================] - ETA: 0s - loss: 2.2588 - accuracy: 0.2800
# Epoch 31: val_accuracy improved from 0.33356 to 0.33449, saving model to checkpoints/flora-transferLearning-1.6986-0.3345.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 2.2588 - accuracy: 0.2800 - val_loss: 1.6986 - val_accuracy: 0.3345
# Epoch 32/60
# 1/1 [==============================] - ETA: 0s - loss: 2.2411 - accuracy: 0.1200
# Epoch 32: val_accuracy improved from 0.33449 to 0.33727, saving model to checkpoints/flora-transferLearning-1.6899-0.3373.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 2.2411 - accuracy: 0.1200 - val_loss: 1.6899 - val_accuracy: 0.3373
# Epoch 33/60
# 1/1 [==============================] - ETA: 0s - loss: 2.0465 - accuracy: 0.2800
# Epoch 33: val_accuracy improved from 0.33727 to 0.33982, saving model to checkpoints/flora-transferLearning-1.6811-0.3398.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 2.0465 - accuracy: 0.2800 - val_loss: 1.6811 - val_accuracy: 0.3398
# Epoch 34/60
# 1/1 [==============================] - ETA: 0s - loss: 2.9395 - accuracy: 0.2800
# Epoch 34: val_accuracy improved from 0.33982 to 0.34399, saving model to checkpoints/flora-transferLearning-1.6720-0.3440.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 2.9395 - accuracy: 0.2800 - val_loss: 1.6720 - val_accuracy: 0.3440
# Epoch 35/60
# 1/1 [==============================] - ETA: 0s - loss: 1.7837 - accuracy: 0.4000
# Epoch 35: val_accuracy improved from 0.34399 to 0.34816, saving model to checkpoints/flora-transferLearning-1.6632-0.3482.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.7837 - accuracy: 0.4000 - val_loss: 1.6632 - val_accuracy: 0.3482
# Epoch 36/60
# 1/1 [==============================] - ETA: 0s - loss: 1.6460 - accuracy: 0.4800
# Epoch 36: val_accuracy improved from 0.34816 to 0.35117, saving model to checkpoints/flora-transferLearning-1.6548-0.3512.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.6460 - accuracy: 0.4800 - val_loss: 1.6548 - val_accuracy: 0.3512
# Epoch 37/60
# 1/1 [==============================] - ETA: 0s - loss: 1.3734 - accuracy: 0.6000
# Epoch 37: val_accuracy improved from 0.35117 to 0.35488, saving model to checkpoints/flora-transferLearning-1.6467-0.3549.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 1.3734 - accuracy: 0.6000 - val_loss: 1.6467 - val_accuracy: 0.3549
# Epoch 38/60
# 1/1 [==============================] - ETA: 0s - loss: 1.3635 - accuracy: 0.6400
# Epoch 38: val_accuracy improved from 0.35488 to 0.35928, saving model to checkpoints/flora-transferLearning-1.6390-0.3593.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.3635 - accuracy: 0.6400 - val_loss: 1.6390 - val_accuracy: 0.3593
# Epoch 39/60
# 1/1 [==============================] - ETA: 0s - loss: 2.0670 - accuracy: 0.2800
# Epoch 39: val_accuracy improved from 0.35928 to 0.36345, saving model to checkpoints/flora-transferLearning-1.6311-0.3634.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.0670 - accuracy: 0.2800 - val_loss: 1.6311 - val_accuracy: 0.3634
# Epoch 40/60
# 1/1 [==============================] - ETA: 0s - loss: 2.0903 - accuracy: 0.3600
# Epoch 40: val_accuracy improved from 0.36345 to 0.36785, saving model to checkpoints/flora-transferLearning-1.6232-0.3678.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 2.0903 - accuracy: 0.3600 - val_loss: 1.6232 - val_accuracy: 0.3678
# Epoch 41/60
# 1/1 [==============================] - ETA: 0s - loss: 1.6599 - accuracy: 0.5200
# Epoch 41: val_accuracy improved from 0.36785 to 0.37318, saving model to checkpoints/flora-transferLearning-1.6152-0.3732.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.6599 - accuracy: 0.5200 - val_loss: 1.6152 - val_accuracy: 0.3732
# Epoch 42/60
# 1/1 [==============================] - ETA: 0s - loss: 1.6906 - accuracy: 0.5600
# Epoch 42: val_accuracy improved from 0.37318 to 0.37897, saving model to checkpoints/flora-transferLearning-1.6076-0.3790.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.6906 - accuracy: 0.5600 - val_loss: 1.6076 - val_accuracy: 0.3790
# Epoch 43/60
# 1/1 [==============================] - ETA: 0s - loss: 1.8963 - accuracy: 0.4400
# Epoch 43: val_accuracy improved from 0.37897 to 0.38151, saving model to checkpoints/flora-transferLearning-1.6000-0.3815.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.8963 - accuracy: 0.4400 - val_loss: 1.6000 - val_accuracy: 0.3815
# Epoch 44/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9926 - accuracy: 0.4000
# Epoch 44: val_accuracy improved from 0.38151 to 0.38476, saving model to checkpoints/flora-transferLearning-1.5920-0.3848.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.9926 - accuracy: 0.4000 - val_loss: 1.5920 - val_accuracy: 0.3848
# Epoch 45/60
# 1/1 [==============================] - ETA: 0s - loss: 1.6600 - accuracy: 0.4000
# Epoch 45: val_accuracy improved from 0.38476 to 0.38962, saving model to checkpoints/flora-transferLearning-1.5843-0.3896.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.6600 - accuracy: 0.4000 - val_loss: 1.5843 - val_accuracy: 0.3896
# Epoch 46/60
# 1/1 [==============================] - ETA: 0s - loss: 1.5176 - accuracy: 0.4000
# Epoch 46: val_accuracy improved from 0.38962 to 0.39263, saving model to checkpoints/flora-transferLearning-1.5769-0.3926.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 1.5176 - accuracy: 0.4000 - val_loss: 1.5769 - val_accuracy: 0.3926
# Epoch 47/60
# 1/1 [==============================] - ETA: 0s - loss: 1.5361 - accuracy: 0.4800
# Epoch 47: val_accuracy improved from 0.39263 to 0.39541, saving model to checkpoints/flora-transferLearning-1.5697-0.3954.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.5361 - accuracy: 0.4800 - val_loss: 1.5697 - val_accuracy: 0.3954
# Epoch 48/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9090 - accuracy: 0.4000
# Epoch 48: val_accuracy improved from 0.39541 to 0.39819, saving model to checkpoints/flora-transferLearning-1.5623-0.3982.hdf5
# 1/1 [==============================] - 23s 23s/step - loss: 1.9090 - accuracy: 0.4000 - val_loss: 1.5623 - val_accuracy: 0.3982
# Epoch 49/60
# 1/1 [==============================] - ETA: 0s - loss: 1.9551 - accuracy: 0.3600
# Epoch 49: val_accuracy improved from 0.39819 to 0.40051, saving model to checkpoints/flora-transferLearning-1.5552-0.4005.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.9551 - accuracy: 0.3600 - val_loss: 1.5552 - val_accuracy: 0.4005
# Epoch 50/60
# 1/1 [==============================] - ETA: 0s - loss: 2.1327 - accuracy: 0.2800
# Epoch 50: val_accuracy improved from 0.40051 to 0.40468, saving model to checkpoints/flora-transferLearning-1.5481-0.4047.hdf5
# 1/1 [==============================] - 22s 22s/step - loss: 2.1327 - accuracy: 0.2800 - val_loss: 1.5481 - val_accuracy: 0.4047
# Epoch 51/60
# 1/1 [==============================] - ETA: 0s - loss: 1.5243 - accuracy: 0.4400
# Epoch 51: val_accuracy improved from 0.40468 to 0.40954, saving model to checkpoints/flora-transferLearning-1.5411-0.4095.hdf5
# 1/1 [==============================] - 24s 24s/step - loss: 1.5243 - accuracy: 0.4400 - val_loss: 1.5411 - val_accuracy: 0.4095
# Epoch 52/60
# 1/1 [==============================] - ETA: 0s - loss: 1.6671 - accuracy: 0.4400
# Epoch 52: val_accuracy improved from 0.40954 to 0.41348, saving model to checkpoints/flora-transferLearning-1.5342-0.4135.hdf5
# 1/1 [==============================] - 42s 42s/step - loss: 1.6671 - accuracy: 0.4400 - val_loss: 1.5342 - val_accuracy: 0.4135

# %%
print(top_model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7fd0340661c0>

# %% [markdown]
# Evaluate on the best model

# %%
from tensorflow.keras.models import load_model
model_saved_name = ""
#flora-transferLearning-1.7142-0.3280.hdf5
best_model = load_model(checkpoint_dir + "flora-transferLearning-1.5058-0.4647.hdf5")
                        #"flora-transferLearning-1.7202-0.3231.hdf5")
                        #"flora-transferLearning-1.6939-0.3410.hdf5")
                        
                        #"flora-transferLearning-1.7142-0.3280.hdf5")#"flora-transferLearning-1.6966-0.3394.hdf5")

# %%
best_model.evaluate_generator(test_generator, steps=len(test_generator))
# Out:
# [1.505781888961792, 0.46467453241348267]

# %%
test_generator.reset()
probabilities = best_model.predict_generator(test_generator, steps=len(test_generator))
predicted_labels = np.argmax(probabilities, axis=-1)

# %%
target_labels = test_generator.classes

# %%
from sklearn import metrics
conf = metrics.confusion_matrix(target_labels, predicted_labels)

# %%
import seaborn as sns

def plot_confusion_matrix(conf, labels, figsize=(8, 8)):
    fig = plt.figure(figsize=figsize)
    heatmap = sns.heatmap(conf, annot=True, fmt="d")
    heatmap.xaxis.set_ticklabels(labels, rotation=45, ha="right", fontsize=12)
    heatmap.yaxis.set_ticklabels(labels, rotation=0, ha="right", fontsize=12)
    plt.xlabel("Predicted label", fontsize=12)
    plt.ylabel("True label", fontsize=12)
    plt.show()

# %%
labels = [""] * num_classes
for k, v in test_generator.class_indices.items():
    labels[v] = k

# %%
plot_confusion_matrix(conf, labels, figsize=(14, 14))

# %%
print(metrics.classification_report(target_labels, predicted_labels, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#        daisy       0.12      0.43      0.19       764
#    dandelion       0.16      0.10      0.12      1052
#         rose       0.54      0.16      0.24       784
#    sunflower       0.08      0.05      0.06       733
#        tulip       0.32      0.13      0.18       984
#
#     accuracy                           0.16      4317
#    macro avg       0.24      0.17      0.16      4317
# weighted avg       0.25      0.16      0.16      4317

# %%
# Find for which images the predicted class is wrong
wrong_images = np.where(predicted_labels != target_labels)[0]

# For every prediction, find the largest probability value;
# this is the probability of the winning class for this image
probs_max = np.max(probabilities, axis=-1)

# Sort the probabilities from the wrong images from low to high
idx = np.argsort(probs_max[wrong_images])

# Reverse the order (high to low), and keep the 5 highest ones
idx = idx[::-1][:5]

# Get the indices of the images with the worst predictions
worst_predictions = wrong_images[idx]

index2class = {v:k for k,v in test_generator.class_indices.items()}

for i in worst_predictions:
    print("%s was predicted as '%s' %.4f\n" % (
        test_generator.filenames[i],
        index2class[predicted_labels[i]],
        probs_max[i]
    ))
# Out:
# tulip/14069841138_e2b403f44f_n.jpg was predicted as 'daisy' 1.0000
#
# sunflower/14921668662_3ffc5b9db3_n.jpg was predicted as 'daisy' 1.0000
#
# sunflower/21728822928_9f6817325a_n.jpg was predicted as 'daisy' 1.0000
#
# tulip/503770507_f397245a6a.jpg was predicted as 'daisy' 1.0000
#
# dandelion/151979452_9832f08b69.jpg was predicted as 'daisy' 1.0000

# %%
from keras.preprocessing import image
import keras.utils as image

img = image.load_img(test_data_dir + test_generator.filenames[worst_predictions[0]])
plt.imshow(img)

# %% [markdown]
# Export to Core ML
# Restart kernel with mlvenv with "source mlvenv/bin/activate" for coremltools part

# %%
# !pip3 install coremltools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting coremltools
#   Downloading coremltools-6.3.0-cp39-none-manylinux1_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<=4.0.0,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from coremltools) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from coremltools) (1.11.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from coremltools) (4.65.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.9/dist-packages (from coremltools) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from coremltools) (23.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->coremltools) (1.3.0)
# Installing collected packages: coremltools
# Successfully installed coremltools-6.3.0

# %%
import coremltools as ct
import os
from tensorflow.keras.models import load_model
# Out:
# WARNING:coremltools:scikit-learn version 1.2.2 is not supported. Minimum required version: 0.17. Maximum required version: 1.1.2. Disabling scikit-learn conversion API.
# WARNING:coremltools:XGBoost version 1.7.5 has not been tested with coremltools. You may run into unexpected errors. XGBoost 1.4.2 is the most recent version that has been tested.

# %%
import tensorflow
#import keras
#import tensorflow.keras
from tensorflow.keras.models import load_model

# %%
label_dir = "ava/"
labels = []
checkpoint_dir = "checkpoints/"
best_model = tensorflow.keras.load_model(checkpoint_dir + "multisnacks-1.6708-0.4054.hdf5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c7fff2e6873b> in <cell line: 4>()
#       2 labels = []
#       3 checkpoint_dir = "checkpoints/"
# ----> 4 best_model = tensorflow.keras.load_model(checkpoint_dir + "multisnacks-1.6708-0.4054.hdf5")
#
# NameError: name 'tensorflow' is not defined

# %%
for i in os.listdir(label_dir):
    if i != '.DS_Store' and i != '._.DS_Store':
        labels.append(i)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-97381aa81c4f> in <cell line: 1>()
# ----> 1 for i in os.listdir(label_dir):
#       2     if i != '.DS_Store' and i != '._.DS_Store':
#       3         labels.append(i)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ava/'

# %%
coreml_model = ct.convert(
    best_model,
    input_names=["image"],
    image_input_names="image",
    output_names="labelProbability",
    predicted_feature_name="label",
    red_bias=-1,
    green_bias=-1,
    blue_bias=-1,
    image_scale=2/255.0,
    class_labels=labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b09beb7dc776> in <cell line: 1>()
#       1 coreml_model = ct.convert(
# ----> 2     best_model,
#       3     input_names=["image"],
#       4     image_input_names="image",
#       5     output_names="labelProbability",
#
# NameError: name 'best_model' is not defined

# %%
coreml_model.author = "Joshua Ball"
coreml_model.short_description = "Image classifier"

coreml_model.input_description["image"] = "Input image"
coreml_model.output_description["labelProbability"]= "Prediction probabilities"
coreml_model.output_description["label"]= "Class label of top prediction"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4e9fe418ac1a> in <cell line: 1>()
# ----> 1 coreml_model.author = "Joshua Ball"
#       2 coreml_model.short_description = "Image classifier"
#       3
#       4 coreml_model.input_description["image"] = "Input image"
#       5 coreml_model.output_description["labelProbability"]= "Prediction probabilities"
#
# NameError: name 'coreml_model' is not defined

# %%
coreml_model.save("MultiSnacks.mlmodel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-ea35613266ca> in <module>
# ----> 1 coreml_model.save("MultiSnacks.mlmodel")
#
# NameError: name 'coreml_model' is not defined

# %%
m = ct.models.MLModel("MultiSnacks.mlmodel")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-107-a840a6c14f1b> in <module>
# ----> 1 m = ct.models.MLModel("MultiSnacks.mlmodel")
#
# /usr/local/lib/python3.9/dist-packages/coremltools/models/model.py in __init__(self, model, is_temp_package, mil_program, skip_model_load, compute_units, weights_dir)
#     339                 self.is_temp_package = is_temp_package
#     340                 self._weights_dir = _try_get_weights_dir_path(model)
# --> 341             self.__proxy__, self._spec, self._framework_error = _get_proxy_and_spec(
#     342                 model, compute_units, skip_model_load=skip_model_load,
#     343             )
#
# /usr/local/lib/python3.9/dist-packages/coremltools/models/model.py in _get_proxy_and_spec(filename, compute_units, skip_model_load)
#     130
#     131     filename = _os.path.expanduser(filename)
# --> 132     specification = _load_spec(filename)
#     133
#     134     if _MLModelProxy and not skip_model_load:
#
# /usr/local/lib/python3.9/dist-packages/coremltools/models/utils.py in load_spec(model_path)
#     220
#     221     spec = _Model_pb2.Model()
# --> 222     with open(specfile, "rb") as f:
#     223         spec.ParseFromString(f.read())
#     224     return spec
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/MultiSnacks.mlmodel'

# %%
import numpy as np
import PIL.Image

# %%
Height = 224  # use the correct input image height
Width = 224  # use the correct input image width

# %%
def load_image(path, resize_to=None):
    # resize_to: (Width, Height)
    img = PIL.Image.open(path)
    if resize_to is not None:
        img = img.resize(resize_to, PIL.Image.ANTIALIAS)
    img_np = np.array(img).astype(np.float32)
    return img_np, img

# %%
_, img = load_image('ava/Ripe/focused_184465770-stock-photo-whole-ripe-avocado.jpg', resize_to=(Width, Height))
out_dict = m.predict({'image': img})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-111-9974cfeda649> in <module>
# ----> 1 _, img = load_image('ava/Ripe/focused_184465770-stock-photo-whole-ripe-avocado.jpg', resize_to=(Width, Height))
#       2 out_dict = m.predict({'image': img})
#
# <ipython-input-110-3fd7f97e3651> in load_image(path, resize_to)
#       1 def load_image(path, resize_to=None):
#       2     # resize_to: (Width, Height)
# ----> 3     img = PIL.Image.open(path)
#       4     if resize_to is not None:
#       5         img = img.resize(resize_to, PIL.Image.ANTIALIAS)
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ava/Ripe/focused_184465770-stock-photo-whole-ripe-avocado.jpg'

# %%
from skimage import io
import matplotlib.pyplot as plt
image = io.imread('a.jpg')

_ = plt.hist(image.ravel(), bins = 256, color = 'orange', )
_ = plt.hist(image[:, :, 0].ravel(), bins = 256, color = 'red', alpha = 0.5)
_ = plt.hist(image[:, :, 1].ravel(), bins = 256, color = 'Green', alpha = 0.5)
_ = plt.hist(image[:, :, 2].ravel(), bins = 256, color = 'Blue', alpha = 0.5)
_ = plt.xlabel('Intensity Value')
_ = plt.ylabel('Count')
_ = plt.legend(['Total', 'Red_Channel', 'Green_Channel', 'Blue_Channel'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-112-fcdc497ddca1> in <module>
#       1 from skimage import io
#       2 import matplotlib.pyplot as plt
# ----> 3 image = io.imread('a.jpg')
#       4
#       5 _ = plt.hist(image.ravel(), bins = 256, color = 'orange', )
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
#      13 @wraps(imageio_imread)
#      14 def imread(*args, **kwargs):
# ---> 15     return np.asarray(imageio_imread(*args, **kwargs))
#
# /usr/local/lib/python3.9/dist-packages/imageio/v2.py in imread(uri, format, **kwargs)
#     224     imopen_args["legacy_mode"] = True
#     225
# --> 226     with imopen(uri, "ri", **imopen_args) as file:
#     227         result = file.read(index=0, **kwargs)
#     228
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/imopen.py in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111         request.format_hint = format_hint
#     112     else:
# --> 113         request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     114
#     115     source = "<bytes>" if isinstance(uri, bytes) else uri
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/request.py in __init__(self, uri, mode, extension, format_hint, **kwargs)
#     245
#     246         # Parse what was given
# --> 247         self._parse_uri(uri)
#     248
#     249         # Set extension
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     405                 # Reading: check that the file exists (but is allowed a dir)
#     406                 if not os.path.exists(fn):
# --> 407                     raise FileNotFoundError("No such file: '%s'" % fn)
#     408             else:
#     409                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/content/a.jpg'

# %%
from mpl_toolkits.axes_grid1 import ImageGrid
fig = plt.figure(figsize=(14., 14.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(1, 5),  # creates 2x2 grid of axes
                 axes_pad=0.0,  # pad between axes in inch.
                 )

image_data = [io.imread('a.jpg'), io.imread('b.jpg'),io.imread('c.jpg'),io.imread('d.jpg'),io.imread('e.jpg')]
for ax, im in zip(grid, image_data):
    # Iterating over the grid returns the Axes.
    ax.imshow(im,interpolation='nearest') 
    ax.set_axis_off()

    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-113-5a85b807eeb5> in <module>
#       6                  )
#       7
# ----> 8 image_data = [io.imread('a.jpg'), io.imread('b.jpg'),io.imread('c.jpg'),io.imread('d.jpg'),io.imread('e.jpg')]
#       9 for ax, im in zip(grid, image_data):
#      10     # Iterating over the grid returns the Axes.
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
#      13 @wraps(imageio_imread)
#      14 def imread(*args, **kwargs):
# ---> 15     return np.asarray(imageio_imread(*args, **kwargs))
#
# /usr/local/lib/python3.9/dist-packages/imageio/v2.py in imread(uri, format, **kwargs)
#     224     imopen_args["legacy_mode"] = True
#     225
# --> 226     with imopen(uri, "ri", **imopen_args) as file:
#     227         result = file.read(index=0, **kwargs)
#     228
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/imopen.py in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111         request.format_hint = format_hint
#     112     else:
# --> 113         request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     114
#     115     source = "<bytes>" if isinstance(uri, bytes) else uri
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/request.py in __init__(self, uri, mode, extension, format_hint, **kwargs)
#     245
#     246         # Parse what was given
# --> 247         self._parse_uri(uri)
#     248
#     249         # Set extension
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     405                 # Reading: check that the file exists (but is allowed a dir)
#     406                 if not os.path.exists(fn):
# --> 407                     raise FileNotFoundError("No such file: '%s'" % fn)
#     408             else:
#     409                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/content/a.jpg'

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow(io.imread('a.jpg'))
ax.set_title('Rose')
#plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7],  orientation='horizontal')
imgplot.set_clim(0.0, 0.7)

ax = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(io.imread('b.jpg'))
imgplot.set_clim(0.0, 0.7)
ax.set_title('Dandelion')
#plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

ax = fig.add_subplot(2, 2, 3)
imgplot = plt.imshow(io.imread('c.jpg'))
imgplot.set_clim(0.0, 0.7)
ax.set_title('Dandelion')
#plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

ax = fig.add_subplot(2, 2, 4)
imgplot = plt.imshow(io.imread('d.jpg'))
imgplot.set_clim(0.0, 0.7)
ax.set_title('Sunflower')
#plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')

ax = fig.add_subplot(1, 2, 1)
imgplot = plt.imshow(io.imread('e.jpg'))
imgplot.set_clim(0.0, 0.7)
ax.set_title('Tulip')
#plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], orientation='horizontal')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-114-54cd32814e08> in <module>
#       1 fig = plt.figure(figsize=(10,10))
#       2 ax = fig.add_subplot(2, 2, 1)
# ----> 3 imgplot = plt.imshow(io.imread('a.jpg'))
#       4 ax.set_title('Rose')
#       5 #plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7],  orientation='horizontal')
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /usr/local/lib/python3.9/dist-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
#      13 @wraps(imageio_imread)
#      14 def imread(*args, **kwargs):
# ---> 15     return np.asarray(imageio_imread(*args, **kwargs))
#
# /usr/local/lib/python3.9/dist-packages/imageio/v2.py in imread(uri, format, **kwargs)
#     224     imopen_args["legacy_mode"] = True
#     225
# --> 226     with imopen(uri, "ri", **imopen_args) as file:
#     227         result = file.read(index=0, **kwargs)
#     228
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/imopen.py in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111         request.format_hint = format_hint
#     112     else:
# --> 113         request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     114
#     115     source = "<bytes>" if isinstance(uri, bytes) else uri
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/request.py in __init__(self, uri, mode, extension, format_hint, **kwargs)
#     245
#     246         # Parse what was given
# --> 247         self._parse_uri(uri)
#     248
#     249         # Set extension
#
# /usr/local/lib/python3.9/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     405                 # Reading: check that the file exists (but is allowed a dir)
#     406                 if not os.path.exists(fn):
# --> 407                     raise FileNotFoundError("No such file: '%s'" % fn)
#     408             else:
#     409                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/content/a.jpg'
